# %% [markdown]
# ## Pandas
#
# * Outcome of section
# * Understand DataFrame and Series
# * How to work with Pandas

# %%
import os
import sys
import pandas as pd
from google.colab import files

# %%
# upload stock_data.csv

files.upload()

# !ls

if not os.path.isfile("stock_data.csv"):
    print("FileDoesNotExist")
    sys.exit(1)

# !head /content/stock_data.csv
# Out:
#      <input type="file" id="files-a73483cc-8e0a-4480-9d9a-10d66c02791e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a73483cc-8e0a-4480-9d9a-10d66c02791e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Introduction to Pandas

# %%
# Load in the data
data = pd.read_csv("stock_data.csv", index_col="Date")

# %%
# Get the type of data
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# display the 5 first rows
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  86.139999  84.342003  84.900002  86.052002   47660500.0  86.052002
# 2020-01-03  90.800003  87.384003  88.099998  88.601997   88892500.0  88.601997
# 2020-01-06  90.311996  88.000000  88.094002  90.307999   50665000.0  90.307999
# 2020-01-07  94.325996  90.671997  92.279999  93.811996   89410500.0  93.811996
# 2020-01-08  99.697998  93.646004  94.739998  98.428001  155721500.0  98.428001

# %%
# get data of a given
data["Close"].head()
# Out:
# Date
# 2020-01-02    86.052002
# 2020-01-03    88.601997
# 2020-01-06    90.307999
# 2020-01-07    93.811996
# 2020-01-08    98.428001
# Name: Close, dtype: float64

# %%
type(data["Close"])
# Out:
# pandas.core.series.Series

# %%
data[['Close', 'Volume']].head()
# Out:
#                 Close       Volume
# Date
# 2020-01-02  86.052002   47660500.0
# 2020-01-03  88.601997   88892500.0
# 2020-01-06  90.307999   50665000.0
# 2020-01-07  93.811996   89410500.0
# 2020-01-08  98.428001  155721500.0

# %%
data.loc['2020-01-02']
# Out:
# High         8.614000e+01
# Low          8.434200e+01
# Open         8.490000e+01
# Close        8.605200e+01
# Volume       4.766050e+07
# Adj Close    8.605200e+01
# Name: 2020-01-02, dtype: float64

# %%
data.loc['2020-01-02':'2020-01-31']
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   86.139999   84.342003   84.900002   86.052002   47660500.0
# 2020-01-03   90.800003   87.384003   88.099998   88.601997   88892500.0
# 2020-01-06   90.311996   88.000000   88.094002   90.307999   50665000.0
# 2020-01-07   94.325996   90.671997   92.279999   93.811996   89410500.0
# 2020-01-08   99.697998   93.646004   94.739998   98.428001  155721500.0
# 2020-01-09   99.760002   94.573997   99.419998   96.267998  142202000.0
# 2020-01-10   96.987999   94.739998   96.358002   95.629997   64797500.0
# 2020-01-13  105.125999   98.400002   98.699997  104.972000  132588000.0
# 2020-01-14  109.482002  104.980003  108.851997  107.584000  144981000.0
# 2020-01-15  107.568001  103.358002  105.952003  103.699997   86844000.0
# 2020-01-16  102.891998   98.433998   98.750000  102.697998  108683500.0
# 2020-01-17  103.134003  100.632004  101.522003  102.099998   68145500.0
# ...

# %%
data.to_excel("stock_data.xlsx")

# %%
data["My Column"] = data["Close"] + 10

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  86.139999  84.342003  84.900002  86.052002   47660500.0
# 2020-01-03  90.800003  87.384003  88.099998  88.601997   88892500.0
# 2020-01-06  90.311996  88.000000  88.094002  90.307999   50665000.0
# 2020-01-07  94.325996  90.671997  92.279999  93.811996   89410500.0
# 2020-01-08  99.697998  93.646004  94.739998  98.428001  155721500.0
#
#             Adj Close   My Column
# Date
# 2020-01-02  86.052002   96.052002
# 2020-01-03  88.601997   98.601997
# 2020-01-06  90.307999  100.307999
# 2020-01-07  93.811996  103.811996
# 2020-01-08  98.428001  108.428001

# %% [markdown]
# ### Series

# %%
l1 = [3,6,-7,2]

# %%
l1
# Out:
# [3, 6, -7, 2]

# %%
s1 = pd.Series(l1)

# %%
s1
# Out:
# 0    3
# 1    6
# 2   -7
# 3    2
# dtype: int64

# %%
l2 = [1, 2, '3', 4]

# %%
s2 = pd.Series(l2)

# %%
s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: object

# %%
s1[0]
# Out:
# 3

# %%
type(s1[0])
# Out:
# numpy.int64

# %%
s1 * 2
# Out:
# 0     6
# 1    12
# 2   -14
# 3     4
# dtype: int64

# %%
s1.values
# Out:
# array([ 3,  6, -7,  2])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s3 = pd.Series(l1, index=[3,4, 1, 2])

# %%
s3
# Out:
# 3    3
# 4    6
# 1   -7
# 2    2
# dtype: int64

# %%
s3.index
# Out:
# Int64Index([3, 4, 1, 2], dtype='int64')

# %%
d = {'Denmark': 2, 'Norway': 1, 'Sewden': 3}

# %%
s4 = pd.Series(d)

# %%
s4
# Out:
# Denmark    2
# Norway     1
# Sewden     3
# dtype: int64

# %%
d2 = {'Denmark': 3, 'Faroe Islands': 2, 'Greenland': 1}

# %%
s5 = pd.Series(d2)

# %%
s5
# Out:
# Denmark          3
# Faroe Islands    2
# Greenland        1
# dtype: int64

# %%
s4 + s5
# Out:
# Denmark          5.0
# Faroe Islands    NaN
# Greenland        NaN
# Norway           NaN
# Sewden           NaN
# dtype: float64

# %% [markdown]
# ### DataFrames - Part I

# %%
data = {
    'Country': ['Denmark']*3 + ['Sweden']*3,
    'Year': [2000, 2010, 2020, 2000, 2010, 2020],
    'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]
}

# %%
data
# Out:
# {'Country': ['Denmark', 'Denmark', 'Denmark', 'Sweden', 'Sweden', 'Sweden'],
#  'Year': [2000, 2010, 2020, 2000, 2010, 2020],
#  'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3

# %%
df['Population']
# Out:
# 0     5.3
# 1     5.5
# 2     5.8
# 3     8.8
# 4     9.3
# 5    10.2
# Name: Population, dtype: float64

# %%
type(df['Population'])
# Out:
# pandas.core.series.Series

# %%
df.head(6)
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %%
df.loc[1]
# Out:
# Country       Denmark
# Year             2010
# Population        5.5
# Name: 1, dtype: object

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1]
# Out:
# Country       Denmark
# Year             2010
# Population        5.5
# Name: 1, dtype: object

# %%
df.iloc[1:2]
# Out:
#    Country  Year  Population
# 1  Denmark  2010         5.5

# %%
df.loc[1:2]
# Out:
#    Country  Year  Population
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8

# %%
df.loc[1:2, "Year"]
# Out:
# 1    2010
# 2    2020
# Name: Year, dtype: int64

# %% [markdown]
# ### DataFrames Part II

# %%
data = {
    'Country': ['Denmark']*3 + ['Sweden']*3,
    'Year': [2000, 2010, 2020, 2000, 2010, 2020],
    'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]
}

# %%
df = pd.DataFrame(data, index=[1, 2, 3, 1, 2, 3])
df.head()
# Out:
#    Country  Year  Population
# 1  Denmark  2000         5.3
# 2  Denmark  2010         5.5
# 3  Denmark  2020         5.8
# 1   Sweden  2000         8.8
# 2   Sweden  2010         9.3

# %%
df.loc[1]
# Out:
#    Country  Year  Population
# 1  Denmark  2000         5.3
# 1   Sweden  2000         8.8

# %%
df.iloc[1]
# Out:
# Country       Denmark
# Year             2010
# Population        5.5
# Name: 2, dtype: object

# %%
df.index
# Out:
# Int64Index([1, 2, 3, 1, 2, 3], dtype='int64')

# %%
df2 = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e', 'f'])
df2
# Out:
#    Country  Year  Population
# a  Denmark  2000         5.3
# b  Denmark  2010         5.5
# c  Denmark  2020         5.8
# d   Sweden  2000         8.8
# e   Sweden  2010         9.3
# f   Sweden  2020        10.2

# %%
# @title Population

from matplotlib import pyplot as plt
df2['Population'].plot(kind='hist', bins=20, title='Population')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df2.loc['c']
# Out:
# Country       Denmark
# Year             2020
# Population        5.8
# Name: c, dtype: object

# %%
df2.loc['c':'e']
# Out:
#    Country  Year  Population
# c  Denmark  2020         5.8
# d   Sweden  2000         8.8
# e   Sweden  2010         9.3

# %%
df2.loc['c':'e', 'Year':'Population']
# Out:
#    Year  Population
# c  2020         5.8
# d  2000         8.8
# e  2010         9.3

# %%
df2.loc['c':'e', ['Country', 'Population']]
# Out:
#    Country  Population
# c  Denmark         5.8
# d   Sweden         8.8
# e   Sweden         9.3

# %% [markdown]
# ### DataFrames Part III

# %%
data = {
    'Country': ['Denmark']*3 + ['Sweden']*3,
    'Year': [2000, 2010, 2020, 2000, 2010, 2020],
    'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %%
df['GDP'] = 20

# %%
df
# Out:
#    Country  Year  Population  GDP
# 0  Denmark  2000         5.3   20
# 1  Denmark  2010         5.5   20
# 2  Denmark  2020         5.8   20
# 3   Sweden  2000         8.8   20
# 4   Sweden  2010         9.3   20
# 5   Sweden  2020        10.2   20

# %%
df['GDP'] = df['Population'] * 1.2
df
# Out:
#    Country  Year  Population    GDP
# 0  Denmark  2000         5.3   6.36
# 1  Denmark  2010         5.5   6.60
# 2  Denmark  2020         5.8   6.96
# 3   Sweden  2000         8.8  10.56
# 4   Sweden  2010         9.3  11.16
# 5   Sweden  2020        10.2  12.24

# %% [markdown]
# ### DataFrames Part IV

# %%
data = {
    'Country': ['Denmark']*3 + ['Sweden']*3,
    'Year': [2000, 2010, 2020, 2000, 2010, 2020],
    'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %%
df['Country'] == 'Denmark'
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# Name: Country, dtype: bool

# %%
df[df['Country'] == 'Denmark']
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8

# %%
df[df['Country'] == 'Sweden']
# Out:
#   Country  Year  Population
# 3  Sweden  2000         8.8
# 4  Sweden  2010         9.3
# 5  Sweden  2020        10.2

# %%
df[df['Population'] >= 5.5]
# Out:
#    Country  Year  Population
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %% [markdown]
# ### DataFames Part V

# %%
data = {
    'Country': ['Denmark']*3 + ['Sweden']*3,
    'Year': [2000, 2010, 2020, 2000, 2010, 2020],
    'Population': [5.3, 5.5, 5.8, 8.8, 9.3, 10.2]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %%
df_c = df.set_index('Country')
df_c
# Out:
#          Year  Population
# Country
# Denmark  2000         5.3
# Denmark  2010         5.5
# Denmark  2020         5.8
# Sweden   2000         8.8
# Sweden   2010         9.3
# Sweden   2020        10.2

# %%
df_c['Year']
# Out:
# Country
# Denmark    2000
# Denmark    2010
# Denmark    2020
# Sweden     2000
# Sweden     2010
# Sweden     2020
# Name: Year, dtype: int64

# %%
df_c['Population']
# Out:
# Country
# Denmark     5.3
# Denmark     5.5
# Denmark     5.8
# Sweden      8.8
# Sweden      9.3
# Sweden     10.2
# Name: Population, dtype: float64

# %%
df_c.loc['Denmark']
# Out:
#          Year  Population
# Country
# Denmark  2000         5.3
# Denmark  2010         5.5
# Denmark  2020         5.8

# %%
df_c.loc['Sweden']
# Out:
#          Year  Population
# Country
# Sweden   2000         8.8
# Sweden   2010         9.3
# Sweden   2020        10.2

# %%
df_cy = df.set_index(['Country', 'Year'])
df_cy
# Out:
#               Population
# Country Year
# Denmark 2000         5.3
#         2010         5.5
#         2020         5.8
# Sweden  2000         8.8
#         2010         9.3
#         2020        10.2

# %%
df_cy.loc['Denmark'].loc[2000]
# Out:
# Population    5.3
# Name: 2000, dtype: float64

# %%
df_cy.index
# Out:
# MultiIndex([('Denmark', 2000),
#             ('Denmark', 2010),
#             ('Denmark', 2020),
#             ( 'Sweden', 2000),
#             ( 'Sweden', 2010),
#             ( 'Sweden', 2020)],
#            names=['Country', 'Year'])

# %%
df_cy.xs(2000, level=1)
# Out:
#          Population
# Country
# Denmark         5.3
# Sweden          8.8

# %% [markdown]
# ### Read and Write with Pandas Part I

# %%
df = pd.read_csv("stock_data.csv", index_col='Date')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  86.139999  84.342003  84.900002  86.052002   47660500.0  86.052002
# 2020-01-03  90.800003  87.384003  88.099998  88.601997   88892500.0  88.601997
# 2020-01-06  90.311996  88.000000  88.094002  90.307999   50665000.0  90.307999
# 2020-01-07  94.325996  90.671997  92.279999  93.811996   89410500.0  93.811996
# 2020-01-08  99.697998  93.646004  94.739998  98.428001  155721500.0  98.428001

# %%
df2 = df[['Close', 'Volume']]
df2.to_csv("test.csv")

# %%
df2.head()
# Out:
#                 Close       Volume
# Date
# 2020-01-02  86.052002   47660500.0
# 2020-01-03  88.601997   88892500.0
# 2020-01-06  90.307999   50665000.0
# 2020-01-07  93.811996   89410500.0
# 2020-01-08  98.428001  155721500.0

# %%
df_read = pd.read_csv("test.csv", index_col='Date')
df_read.head()
# Out:
#                 Close       Volume
# Date
# 2020-01-02  86.052002   47660500.0
# 2020-01-03  88.601997   88892500.0
# 2020-01-06  90.307999   50665000.0
# 2020-01-07  93.811996   89410500.0
# 2020-01-08  98.428001  155721500.0

# %% [markdown]
# ### Read and Write with Pandas Part II

# %%
# reading in excel files

data = pd.read_excel("stock_data.xlsx", index_col='Date', engine='openpyxl')

# %%
data.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2020-01-02  86.139999  84.342003  84.900002  86.052002   47660500  86.052002
# 2020-01-03  90.800003  87.384003  88.099998  88.601997   88892500  88.601997
# 2020-01-06  90.311996  88.000000  88.094002  90.307999   50665000  90.307999
# 2020-01-07  94.325996  90.671997  92.279999  93.811996   89410500  93.811996
# 2020-01-08  99.697998  93.646004  94.739998  98.428001  155721500  98.428001

# %%
# !pip install xlsxwriter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import xlsxwriter

# %%
excel_file = 'output.xlsx'
sheet_name = 'Stock prices'
writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
data.to_excel(writer, sheet_name=sheet_name)

# Access the xlsxwriter workbook and worksheet objects from the dataframe
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a line chart object
chart = workbook.add_chart({'type': 'line'})

# Get the number of rows and column Index
max_row = len(data)
col_x = 0 # this is the index
col_y = data.columns.get_loc('Close') + 1

# Add a data to our chart
chart.add_series({
    'name': 'Price',
    'categories': [sheet_name, 1, col_x, max_row, col_x],
    'values': [sheet_name, 1, col_y, max_row, col_y],
})

# Set names on axis
chart.set_x_axis({'name': 'Date'})
chart.set_y_axis({'name': 'Price', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet in field H2
worksheet.insert_chart('H2', chart)

# Close and save the Excel file
writer.save()
# Out:
# <ipython-input-89-56baf30938c6>:33: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# ### Read and Write with Pandas Part III

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_past_and_projected_GDP_(nominal)"
tables = pd.read_html(url)
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 12

# %%
tables[0]
# Out:
#     Country (or area)     1970     1971     1972     1973     1974     1975  \
# 0       Afghanistan *   1749.0   1831.0   1596.0   1733.0   2156.0   2367.0
# 1           Albania *   2266.0   2331.0   2398.0   2467.0   2537.0   2610.0
# 2           Algeria *   5167.0   5376.0   7193.0   9250.0  13290.0  15591.0
# 3           Andorra *     99.0    113.0    144.0    191.0    236.0    279.0
# 4            Angola *   3807.0   4007.0   4102.0   5016.0   5627.0   4147.0
# ..                ...      ...      ...      ...      ...      ...      ...
# 213       South Yemen    154.0    142.0    159.0    130.0    138.0    141.0
# 214      Yugoslavia *  14554.0  15802.0  16485.0  21472.0  29706.0  33279.0
# 215          Zambia *   1544.0   1574.0   1852.0   2350.0   2895.0   2658.0
# 216        Zanzibar *      NaN      NaN      NaN      NaN      NaN      NaN
# 217        Zimbabwe *   2023.0   2339.0   2888.0   3552.0   4274.0   4692.0
#
#         1976     1977     1978     1979
# ...

# %%
type(tables[0])
# Out:
# pandas.core.frame.DataFrame

# %%
tables[1].head()
# Out:
#   Country (or dependent territory)     1980     1981     1982     1983  \
# 0                      Afghanistan      NaN      NaN      NaN      NaN
# 1                          Albania   1946.0   2229.0   2296.0   2319.0
# 2                          Algeria  42346.0  44372.0  44780.0  47529.0
# 3                          Andorra      NaN      NaN      NaN      NaN
# 4                           Angola   6639.0   6214.0   6214.0   6476.0
#
#       1984     1985     1986     1987     1988     1989
# 0      NaN      NaN      NaN      NaN      NaN      NaN
# 1   2290.0   2339.0   2587.0   2566.0   2530.0   2779.0
# 2  51513.0  61132.0  61535.0  63300.0  51664.0  52558.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN
# 4   6864.0   8457.0   7918.0   9050.0   9818.0  11421.0

# %%
tables[0].to_csv("gdp-80s.csv", index=False)

# %%
tables[1].to_csv("gdp-90s.csv", index=False)

# %%
tables[2].to_csv("gdp-00s.csv", index=False)

# %%
tables[3].to_csv("gdp-10s.csv", index=False)

# %% [markdown]
# ### Merge - Join - Concatenate Part I

# %%
df1 = pd.DataFrame({'a': [1, 2, 3, 4], 'b': [5, 6, 7, 8]})

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df2 = pd.DataFrame({'b': [5, 6, 7, 8], 'c': [9, 10, 11, 12]})

# %%
df2
# Out:
#    b   c
# 0  5   9
# 1  6  10
# 2  7  11
# 3  8  12

# %%
pd.concat([df1, df2])
# Out:
#      a  b     c
# 0  1.0  5   NaN
# 1  2.0  6   NaN
# 2  3.0  7   NaN
# 3  4.0  8   NaN
# 0  NaN  5   9.0
# 1  NaN  6  10.0
# 2  NaN  7  11.0
# 3  NaN  8  12.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    a  b  b   c
# 0  1  5  5   9
# 1  2  6  6  10
# 2  3  7  7  11
# 3  4  8  8  12

# %%
pd.merge(df1, df2, on='b')
# Out:
#    a  b   c
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
df3 = pd.DataFrame({'b': [8, 7, 6, 5], 'c': [1 ,2 ,3, 4]})

# %%
df3
# Out:
#    b  c
# 0  8  1
# 1  7  2
# 2  6  3
# 3  5  4

# %%
pd.merge(df1, df3, on='b')
# Out:
#    a  b  c
# 0  1  5  4
# 1  2  6  3
# 2  3  7  2
# 3  4  8  1

# %%
df4 = pd.DataFrame({'c': [1, 2, 3, 4], 'd': [5, 6, 7, 8]})
df4
# Out:
#    c  d
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df1.join(df4)
# Out:
#    a  b  c  d
# 0  1  5  1  5
# 1  2  6  2  6
# 2  3  7  3  7
# 3  4  8  4  8

# %% [markdown]
# ### Merge - Join - Concatenate Part II

# %%
gdp80 = pd.read_csv("gdp-80s.csv")
gdp80.head()
# Out:
#   Country (or area)    1970    1971    1972    1973     1974     1975  \
# 0     Afghanistan *  1749.0  1831.0  1596.0  1733.0   2156.0   2367.0
# 1         Albania *  2266.0  2331.0  2398.0  2467.0   2537.0   2610.0
# 2         Algeria *  5167.0  5376.0  7193.0  9250.0  13290.0  15591.0
# 3         Andorra *    99.0   113.0   144.0   191.0    236.0    279.0
# 4          Angola *  3807.0  4007.0  4102.0  5016.0   5627.0   4147.0
#
#       1976     1977     1978     1979
# 0   2556.0   2953.0   3300.0   3698.0
# 1   2686.0   2761.0   2842.0   2372.0
# 2  17790.0  21038.0  26433.0  33276.0
# 3    288.0    321.0    390.0    521.0
# 4   3981.0   4344.0   4845.0   5380.0

# %%
gdp90 = pd.read_csv("gdp-90s.csv")
gdp90.head()
# Out:
#   Country (or dependent territory)     1980     1981     1982     1983  \
# 0                      Afghanistan      NaN      NaN      NaN      NaN
# 1                          Albania   1946.0   2229.0   2296.0   2319.0
# 2                          Algeria  42346.0  44372.0  44780.0  47529.0
# 3                          Andorra      NaN      NaN      NaN      NaN
# 4                           Angola   6639.0   6214.0   6214.0   6476.0
#
#       1984     1985     1986     1987     1988     1989
# 0      NaN      NaN      NaN      NaN      NaN      NaN
# 1   2290.0   2339.0   2587.0   2566.0   2530.0   2779.0
# 2  51513.0  61132.0  61535.0  63300.0  51664.0  52558.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN
# 4   6864.0   8457.0   7918.0   9050.0   9818.0  11421.0

# %%
gdp00 = pd.read_csv("gdp-00s.csv")
gdp00.head()
# Out:
#   Country (or dependent territory)     1990     1991     1992     1993  \
# 0                      Afghanistan      NaN      NaN      NaN      NaN
# 1                          Albania   2221.0   1333.0    843.0   1461.0
# 2                          Algeria  61892.0  46670.0  49217.0  50963.0
# 3                          Andorra      NaN      NaN      NaN      NaN
# 4                           Angola  12571.0  12186.0   9395.0   6819.0
#
#       1994     1995     1996     1997     1998     1999
# 0      NaN      NaN      NaN      NaN      NaN      NaN
# 1   2361.0   2882.0   3200.0   2259.0   2560.0   3209.0
# 2  42426.0  42066.0  46941.0  48178.0  48188.0  48845.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN
# 4   4965.0   6197.0   7994.0   9388.0   7958.0   7526.0

# %%
gdp10 = pd.read_csv("gdp-10s.csv")
gdp10.head()
# Out:
#   Country (or dependent territory)     2000     2001     2002     2003  \
# 0                      Afghanistan      NaN      NaN   4367.0   4553.0
# 1                          Albania   3483.0   3928.0   4348.0   5611.0
# 2                          Algeria  54749.0  54745.0  56761.0  67864.0
# 3                          Andorra   1429.0   1547.0   1758.0   2362.0
# 4                           Angola  11166.0  10930.0  15286.0  17813.0
#
#       2004      2005      2006      2007      2008      2009
# 0   5146.0    6167.0    6925.0    8556.0   10297.0   12066.0
# 1   7185.0    8052.0    8896.0   10677.0   12881.0   12044.0
# 2  85332.0  103198.0  117027.0  134977.0  171001.0  137211.0
# 3   2896.0    3158.0    3456.0    3952.0    4082.0    3675.0
# 4  23552.0   36971.0   52381.0   65266.0   88539.0   70307.0

# %%
gdp = pd.concat([gdp80, gdp90, gdp00, gdp10], axis=1)

# %%
gdp.head()
# Out:
#   Country (or area)    1970    1971    1972    1973     1974     1975  \
# 0     Afghanistan *  1749.0  1831.0  1596.0  1733.0   2156.0   2367.0
# 1         Albania *  2266.0  2331.0  2398.0  2467.0   2537.0   2610.0
# 2         Algeria *  5167.0  5376.0  7193.0  9250.0  13290.0  15591.0
# 3         Andorra *    99.0   113.0   144.0   191.0    236.0    279.0
# 4          Angola *  3807.0  4007.0  4102.0  5016.0   5627.0   4147.0
#
#       1976     1977     1978  ...     2000     2001     2002     2003  \
# 0   2556.0   2953.0   3300.0  ...      NaN      NaN   4367.0   4553.0
# 1   2686.0   2761.0   2842.0  ...   3483.0   3928.0   4348.0   5611.0
# 2  17790.0  21038.0  26433.0  ...  54749.0  54745.0  56761.0  67864.0
# 3    288.0    321.0    390.0  ...   1429.0   1547.0   1758.0   2362.0
# 4   3981.0   4344.0   4845.0  ...  11166.0  10930.0  15286.0  17813.0
#
#       2004      2005      2006      2007      2008      2009
# 0   5146.0    6167.0    6925.0    8556.0   10297.0   12066.0
# ...

# %%
gdp
# Out:
#     Country (or area)     1970     1971     1972     1973     1974     1975  \
# 0       Afghanistan *   1749.0   1831.0   1596.0   1733.0   2156.0   2367.0
# 1           Albania *   2266.0   2331.0   2398.0   2467.0   2537.0   2610.0
# 2           Algeria *   5167.0   5376.0   7193.0   9250.0  13290.0  15591.0
# 3           Andorra *     99.0    113.0    144.0    191.0    236.0    279.0
# 4            Angola *   3807.0   4007.0   4102.0   5016.0   5627.0   4147.0
# ..                ...      ...      ...      ...      ...      ...      ...
# 213       South Yemen    154.0    142.0    159.0    130.0    138.0    141.0
# 214      Yugoslavia *  14554.0  15802.0  16485.0  21472.0  29706.0  33279.0
# 215          Zambia *   1544.0   1574.0   1852.0   2350.0   2895.0   2658.0
# 216        Zanzibar *      NaN      NaN      NaN      NaN      NaN      NaN
# 217        Zimbabwe *   2023.0   2339.0   2888.0   3552.0   4274.0   4692.0
#
# ...

# %%
gdp.to_csv("gdp.csv",)

# %% [markdown]
# ### Transpose and clean data

# %%
# upload gdp_local.csv
files.upload()

if not os.path.isfile("gdp_local.csv"):
    print("gdp_local.csv file does not exist...")
    print("upload")
    sys.exit(1)
# Out:
#      <input type="file" id="files-8f35ce15-b7cf-4311-88d2-dc246dc53315" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f35ce15-b7cf-4311-88d2-dc246dc53315">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gdp = pd.read_csv("gdp_local.csv", index_col=0)
gdp.head()
# Out:
#                         1980     1981      1982      1983      1984      1985  \
# Afghanistan              NaN      NaN       NaN       NaN       NaN       NaN
# Albania               5547.0   6410.0    7005.0    7362.0    7776.0    7904.0
# Algeria              86255.0  97138.0  109768.0  120263.0  131504.0  143312.0
# Angola               14949.0  15626.0   16595.0   17975.0   19729.0   21073.0
# Antigua and Barbuda    276.0    312.0     328.0     363.0     415.0     460.0
#
#                          1986      1987      1988      1989  ...      2010  \
# Afghanistan               NaN       NaN       NaN       NaN  ...   46304.0
# Albania                8515.0    8662.0    8840.0   10084.0  ...   28328.0
# Algeria              145909.0  148586.0  150865.0  164255.0  ...  471508.0
# Angola                22122.0   23613.0   25937.0   26957.0  ...  153871.0
# Antigua and Barbuda     508.0     558.0     609.0     671.0  ...    1814.0
#
# ...

# %%
gdp.T
# Out:
#       Afghanistan  Albania   Algeria    Angola  Antigua and Barbuda  \
# 1980          NaN   5547.0   86255.0   14949.0                276.0
# 1981          NaN   6410.0   97138.0   15626.0                312.0
# 1982          NaN   7005.0  109768.0   16595.0                328.0
# 1983          NaN   7362.0  120263.0   17975.0                363.0
# 1984          NaN   7776.0  131504.0   19729.0                415.0
# 1985          NaN   7904.0  143312.0   21073.0                460.0
# 1986          NaN   8515.0  145909.0   22122.0                508.0
# 1987          NaN   8662.0  148586.0   23613.0                558.0
# 1988          NaN   8840.0  150865.0   25937.0                609.0
# 1989          NaN  10084.0  164255.0   26957.0                671.0
# 1990          NaN   9411.0  171693.0   26989.0                715.0
# 1991          NaN   7002.0  175279.0   28164.0                758.0
# 1992          NaN   6646.0  182143.0   27125.0                783.0
# ...

# %%
gdp_t = gdp.transpose()
gdp_t
# Out:
#       Afghanistan  Albania   Algeria    Angola  Antigua and Barbuda  \
# 1980          NaN   5547.0   86255.0   14949.0                276.0
# 1981          NaN   6410.0   97138.0   15626.0                312.0
# 1982          NaN   7005.0  109768.0   16595.0                328.0
# 1983          NaN   7362.0  120263.0   17975.0                363.0
# 1984          NaN   7776.0  131504.0   19729.0                415.0
# 1985          NaN   7904.0  143312.0   21073.0                460.0
# 1986          NaN   8515.0  145909.0   22122.0                508.0
# 1987          NaN   8662.0  148586.0   23613.0                558.0
# 1988          NaN   8840.0  150865.0   25937.0                609.0
# 1989          NaN  10084.0  164255.0   26957.0                671.0
# 1990          NaN   9411.0  171693.0   26989.0                715.0
# 1991          NaN   7002.0  175279.0   28164.0                758.0
# 1992          NaN   6646.0  182143.0   27125.0                783.0
# ...

# %%
gdp_t.fillna(0)
# Out:
#       Afghanistan  Albania   Algeria    Angola  Antigua and Barbuda  \
# 1980          0.0   5547.0   86255.0   14949.0                276.0
# 1981          0.0   6410.0   97138.0   15626.0                312.0
# 1982          0.0   7005.0  109768.0   16595.0                328.0
# 1983          0.0   7362.0  120263.0   17975.0                363.0
# 1984          0.0   7776.0  131504.0   19729.0                415.0
# 1985          0.0   7904.0  143312.0   21073.0                460.0
# 1986          0.0   8515.0  145909.0   22122.0                508.0
# 1987          0.0   8662.0  148586.0   23613.0                558.0
# 1988          0.0   8840.0  150865.0   25937.0                609.0
# 1989          0.0  10084.0  164255.0   26957.0                671.0
# 1990          0.0   9411.0  171693.0   26989.0                715.0
# 1991          0.0   7002.0  175279.0   28164.0                758.0
# 1992          0.0   6646.0  182143.0   27125.0                783.0
# ...

# %%
# axis=1 drops columns with na
# axis=0 drops rows with na (dangerous) might delete all
gdp_t.dropna(axis=1)
# Out:
#       Albania   Algeria    Angola  Antigua and Barbuda  Argentina  Australia  \
# 1980   5547.0   86255.0   14949.0                276.0   176595.0   154527.0
# 1981   6410.0   97138.0   15626.0                312.0   181994.0   175929.0
# 1982   7005.0  109768.0   16595.0                328.0   187200.0   186961.0
# 1983   7362.0  120263.0   17975.0                363.0   201854.0   193421.0
# 1984   7776.0  131504.0   19729.0                415.0   213199.0   212996.0
# 1985   7904.0  143312.0   21073.0                460.0   204727.0   231806.0
# 1986   8515.0  145909.0   22122.0                508.0   223778.0   242268.0
# 1987   8662.0  148586.0   23613.0                558.0   235293.0   260608.0
# 1988   8840.0  150865.0   25937.0                609.0   238765.0   281203.0
# 1989  10084.0  164255.0   26957.0                671.0   230669.0   305637.0
# 1990   9411.0  171693.0   26989.0                715.0   236001.0   321669.0
# ...

# %% [markdown]
# ### Views

# %%
gdp = gdp.transpose()

# %%
gdp.head()
# Out:
#       Afghanistan  Albania   Algeria   Angola  Antigua and Barbuda  Argentina  \
# 1980          NaN   5547.0   86255.0  14949.0                276.0   176595.0
# 1981          NaN   6410.0   97138.0  15626.0                312.0   181994.0
# 1982          NaN   7005.0  109768.0  16595.0                328.0   187200.0
# 1983          NaN   7362.0  120263.0  17975.0                363.0   201854.0
# 1984          NaN   7776.0  131504.0  19729.0                415.0   213199.0
#
#       Armenia  Australia   Austria  Azerbaijan  ...  Uzbekistan  Vanuatu  \
# 1980      NaN   154527.0   84466.0         NaN  ...         NaN    110.0
# 1981      NaN   175929.0   92261.0         NaN  ...         NaN    125.0
# 1982      NaN   186961.0   99855.0         NaN  ...         NaN    135.0
# 1983      NaN   193421.0  106708.0         NaN  ...         NaN    145.0
# 1984      NaN   212996.0  110861.0         NaN  ...         NaN    164.0
#
# ...

# %%
gdp_view = gdp.loc["1980"]

# %%
gdp_view
# Out:
# Afghanistan                NaN
# Albania                 5547.0
# Algeria                86255.0
# Angola                 14949.0
# Antigua and Barbuda      276.0
#                         ...
# Zambia                  8014.0
# Zimbabwe                   NaN
# Aruba                      NaN
# Palestine                  NaN
# Somalia                    NaN
# Name: 1980, Length: 195, dtype: float64

# %%
gdp_view["Afghanistan"] = 0

# %%
gdp_view
# Out:
# Afghanistan                0.0
# Albania                 5547.0
# Algeria                86255.0
# Angola                 14949.0
# Antigua and Barbuda      276.0
#                         ...
# Zambia                  8014.0
# Zimbabwe                   NaN
# Aruba                      NaN
# Palestine                  NaN
# Somalia                    NaN
# Name: 1980, Length: 195, dtype: float64

# %%
gdp.head()
# Out:
#       Afghanistan  Albania   Algeria   Angola  Antigua and Barbuda  Argentina  \
# 1980          0.0   5547.0   86255.0  14949.0                276.0   176595.0
# 1981          NaN   6410.0   97138.0  15626.0                312.0   181994.0
# 1982          NaN   7005.0  109768.0  16595.0                328.0   187200.0
# 1983          NaN   7362.0  120263.0  17975.0                363.0   201854.0
# 1984          NaN   7776.0  131504.0  19729.0                415.0   213199.0
#
#       Armenia  Australia   Austria  Azerbaijan  ...  Uzbekistan  Vanuatu  \
# 1980      NaN   154527.0   84466.0         NaN  ...         NaN    110.0
# 1981      NaN   175929.0   92261.0         NaN  ...         NaN    125.0
# 1982      NaN   186961.0   99855.0         NaN  ...         NaN    135.0
# 1983      NaN   193421.0  106708.0         NaN  ...         NaN    145.0
# 1984      NaN   212996.0  110861.0         NaN  ...         NaN    164.0
#
# ...

# %%
gdp_copy = gdp.loc["1980"].copy()
gdp_copy
# Out:
# Afghanistan                0.0
# Albania                 5547.0
# Algeria                86255.0
# Angola                 14949.0
# Antigua and Barbuda      276.0
#                         ...
# Zambia                  8014.0
# Zimbabwe                   NaN
# Aruba                      NaN
# Palestine                  NaN
# Somalia                    NaN
# Name: 1980, Length: 195, dtype: float64

# %%
gdp_copy["Afghanistan"] = 10
gdp_copy
# Out:
# Afghanistan               10.0
# Albania                 5547.0
# Algeria                86255.0
# Angola                 14949.0
# Antigua and Barbuda      276.0
#                         ...
# Zambia                  8014.0
# Zimbabwe                   NaN
# Aruba                      NaN
# Palestine                  NaN
# Somalia                    NaN
# Name: 1980, Length: 195, dtype: float64

# %%
gdp.head()
# Out:
#       Afghanistan  Albania   Algeria   Angola  Antigua and Barbuda  Argentina  \
# 1980          0.0   5547.0   86255.0  14949.0                276.0   176595.0
# 1981          NaN   6410.0   97138.0  15626.0                312.0   181994.0
# 1982          NaN   7005.0  109768.0  16595.0                328.0   187200.0
# 1983          NaN   7362.0  120263.0  17975.0                363.0   201854.0
# 1984          NaN   7776.0  131504.0  19729.0                415.0   213199.0
#
#       Armenia  Australia   Austria  Azerbaijan  ...  Uzbekistan  Vanuatu  \
# 1980      NaN   154527.0   84466.0         NaN  ...         NaN    110.0
# 1981      NaN   175929.0   92261.0         NaN  ...         NaN    125.0
# 1982      NaN   186961.0   99855.0         NaN  ...         NaN    135.0
# 1983      NaN   193421.0  106708.0         NaN  ...         NaN    145.0
# 1984      NaN   212996.0  110861.0         NaN  ...         NaN    164.0
#
# ...

# %% [markdown]
# ### Useful methods to know

# %%
gdp = pd.read_csv("gdp_local.csv", index_col=0)
gdp.head()
# Out:
#                         1980     1981      1982      1983      1984      1985  \
# Afghanistan              NaN      NaN       NaN       NaN       NaN       NaN
# Albania               5547.0   6410.0    7005.0    7362.0    7776.0    7904.0
# Algeria              86255.0  97138.0  109768.0  120263.0  131504.0  143312.0
# Angola               14949.0  15626.0   16595.0   17975.0   19729.0   21073.0
# Antigua and Barbuda    276.0    312.0     328.0     363.0     415.0     460.0
#
#                          1986      1987      1988      1989  ...      2010  \
# Afghanistan               NaN       NaN       NaN       NaN  ...   46304.0
# Albania                8515.0    8662.0    8840.0   10084.0  ...   28328.0
# Algeria              145909.0  148586.0  150865.0  164255.0  ...  471508.0
# Angola                22122.0   23613.0   25937.0   26957.0  ...  153871.0
# Antigua and Barbuda     508.0     558.0     609.0     671.0  ...    1814.0
#
# ...

# %%
gdp_2019 = gdp["2019"]
gdp_2019.head()
# Out:
# Afghanistan             81880.0
# Albania                 41709.0
# Algeria                509307.0
# Angola                 222459.0
# Antigua and Barbuda      2181.0
# Name: 2019, dtype: float64

# %%
gdp_2019.sum()
# Out:
# 134556917.0

# %%
gdp_2019.mean()
# Out:
# 693592.3556701031

# %%
gdp_2019.min()
# Out:
# 49.0

# %%
gdp_2019.max()
# Out:
# 23393004.0

# %%
gdp_2019.sort_values(ascending=False)
# Out:
# China               23393004.0
# United States       21433225.0
# India                9542255.0
# Japan                5450654.0
# Germany              4672006.0
#                        ...
# Kiribati                 251.0
# Marshall Islands         216.0
# Nauru                    125.0
# Tuvalu                    49.0
# Syria                      NaN
# Name: 2019, Length: 195, dtype: float64

# %%
gdp.sort_values('2019', ascending=False)
# Out:
#                        1980       1981       1982       1983       1984  \
# China              305945.0   351572.0   406990.0   468745.0   559159.0
# United States     2862475.0  3210950.0  3345000.0  3638125.0  4040700.0
# India              381961.0   442709.0   486519.0   542586.0   583309.0
# Japan             1027017.0  1169815.0  1284347.0  1375908.0  1488337.0
# Germany            866222.0   948148.0   999039.0  1054620.0  1122911.0
# ...                     ...        ...        ...        ...        ...
# Kiribati               58.0       62.0       70.0       72.0       78.0
# Marshall Islands        NaN        NaN        NaN        NaN        NaN
# Nauru                   NaN        NaN        NaN        NaN        NaN
# Tuvalu                  NaN        NaN        NaN        NaN        NaN
# Syria               18886.0    22397.0    24401.0    25771.0    24952.0
#
#                        1985       1986       1987       1988       1989  ...  \
# ...

# %%
gdp.loc['China'].mean()
# Out:
# 6789784.2

# %%
gdp.loc['United States'].mean()
# Out:
# 10591677.5

# %%
gdp['Mean'] = gdp.mean(axis=1)

# %%
gdp.head()
# Out:
#                         1980     1981      1982      1983      1984      1985  \
# Afghanistan              NaN      NaN       NaN       NaN       NaN       NaN
# Albania               5547.0   6410.0    7005.0    7362.0    7776.0    7904.0
# Algeria              86255.0  97138.0  109768.0  120263.0  131504.0  143312.0
# Angola               14949.0  15626.0   16595.0   17975.0   19729.0   21073.0
# Antigua and Barbuda    276.0    312.0     328.0     363.0     415.0     460.0
#
#                          1986      1987      1988      1989  ...      2011  \
# Afghanistan               NaN       NaN       NaN       NaN  ...   50334.0
# Albania                8515.0    8662.0    8840.0   10084.0  ...   29655.0
# Algeria              145909.0  148586.0  150865.0  164255.0  ...  494947.0
# Angola                22122.0   23613.0   25937.0   26957.0  ...  162539.0
# Antigua and Barbuda     508.0     558.0     609.0     671.0  ...    1816.0
#
# ...

# %%
gdp.sort_values('Mean', ascending=False)
# Out:
#                        1980       1981       1982       1983       1984  \
# United States     2862475.0  3210950.0  3345000.0  3638125.0  4040700.0
# China              305945.0   351572.0   406990.0   468745.0   559159.0
# Japan             1027017.0  1169815.0  1284347.0  1375908.0  1488337.0
# India              381961.0   442709.0   486519.0   542586.0   583309.0
# Russia                  NaN        NaN        NaN        NaN        NaN
# ...                     ...        ...        ...        ...        ...
# Palau                   NaN        NaN        NaN        NaN        NaN
# Marshall Islands        NaN        NaN        NaN        NaN        NaN
# Kiribati               58.0       62.0       70.0       72.0       78.0
# Nauru                   NaN        NaN        NaN        NaN        NaN
# Tuvalu                  NaN        NaN        NaN        NaN        NaN
#
#                        1985       1986       1987       1988       1989  ...  \
# ...

# %%
gdp.drop("Mean", axis=1, inplace=True)

# %%
gdp.head()
# Out:
#                         1980     1981      1982      1983      1984      1985  \
# Afghanistan              NaN      NaN       NaN       NaN       NaN       NaN
# Albania               5547.0   6410.0    7005.0    7362.0    7776.0    7904.0
# Algeria              86255.0  97138.0  109768.0  120263.0  131504.0  143312.0
# Angola               14949.0  15626.0   16595.0   17975.0   19729.0   21073.0
# Antigua and Barbuda    276.0    312.0     328.0     363.0     415.0     460.0
#
#                          1986      1987      1988      1989  ...      2010  \
# Afghanistan               NaN       NaN       NaN       NaN  ...   46304.0
# Albania                8515.0    8662.0    8840.0   10084.0  ...   28328.0
# Algeria              145909.0  148586.0  150865.0  164255.0  ...  471508.0
# Angola                22122.0   23613.0   25937.0   26957.0  ...  153871.0
# Antigua and Barbuda     508.0     558.0     609.0     671.0  ...    1814.0
#
# ...

# %%
gdp_t = gdp.transpose()
gdp_t.head()
# Out:
#       Afghanistan  Albania   Algeria   Angola  Antigua and Barbuda  Argentina  \
# 1980          NaN   5547.0   86255.0  14949.0                276.0   176595.0
# 1981          NaN   6410.0   97138.0  15626.0                312.0   181994.0
# 1982          NaN   7005.0  109768.0  16595.0                328.0   187200.0
# 1983          NaN   7362.0  120263.0  17975.0                363.0   201854.0
# 1984          NaN   7776.0  131504.0  19729.0                415.0   213199.0
#
#       Armenia  Australia   Austria  Azerbaijan  ...  Uzbekistan  Vanuatu  \
# 1980      NaN   154527.0   84466.0         NaN  ...         NaN    110.0
# 1981      NaN   175929.0   92261.0         NaN  ...         NaN    125.0
# 1982      NaN   186961.0   99855.0         NaN  ...         NaN    135.0
# 1983      NaN   193421.0  106708.0         NaN  ...         NaN    145.0
# 1984      NaN   212996.0  110861.0         NaN  ...         NaN    164.0
#
# ...

# %%
diff_gdp = gdp_t.diff()
diff_gdp.head()
# Out:
#       Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  Argentina  \
# 1980          NaN      NaN      NaN     NaN                  NaN        NaN
# 1981          NaN    863.0  10883.0   677.0                 36.0     5399.0
# 1982          NaN    595.0  12630.0   969.0                 16.0     5206.0
# 1983          NaN    357.0  10495.0  1380.0                 35.0    14654.0
# 1984          NaN    414.0  11241.0  1754.0                 52.0    11345.0
#
#       Armenia  Australia  Austria  Azerbaijan  ...  Uzbekistan  Vanuatu  \
# 1980      NaN        NaN      NaN         NaN  ...         NaN      NaN
# 1981      NaN    21402.0   7795.0         NaN  ...         NaN     15.0
# 1982      NaN    11032.0   7594.0         NaN  ...         NaN     10.0
# 1983      NaN     6460.0   6853.0         NaN  ...         NaN     10.0
# 1984      NaN    19575.0   4153.0         NaN  ...         NaN     19.0
#
# ...

# %% [markdown]
# ### Apply - an awesome method to master

# %%
df = pd.DataFrame({'a': [1,2,3,4], 'b': [5,6,7,8]})
df
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
def my_func(x):
    return x + 2

# %%
df.apply(my_func)
# Out:
#    a   b
# 0  3   7
# 1  4   8
# 2  5   9
# 3  6  10

# %%
df.apply(lambda x: x + 2)
# Out:
#    a   b
# 0  3   7
# 1  4   8
# 2  5   9
# 3  6  10

# %%
df['a'].apply(lambda x : x + 2)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# Name: a, dtype: int64

# %%
df['c'] = df['a'].apply(lambda x : x + 2)
df
# Out:
#    a  b  c
# 0  1  5  3
# 1  2  6  4
# 2  3  7  5
# 3  4  8  6

# %%
df['d'] = df['a'] + 2
df
# Out:
#    a  b  c  d
# 0  1  5  3  3
# 1  2  6  4  4
# 2  3  7  5  5
# 3  4  8  6  6

# %%
df.apply(len, axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# dtype: int64

# %%
df.apply(lambda x : x.loc[0] + x.loc[1])
# Out:
# a     3
# b    11
# c     7
# d     7
# dtype: int64

# %%
df.apply(lambda x: x['a'] - x['b'], axis=1)
# Out:
# 0   -4
# 1   -4
# 2   -4
# 3   -4
# dtype: int64

# %% [markdown]
# ### Exercises

# %%
gdp00 = pd.read_csv("gdp-00s.csv", index_col=0)
gdp00.head()
# Out:
#                                      1990     1991     1992     1993     1994  \
# Country (or dependent territory)
# Afghanistan                           NaN      NaN      NaN      NaN      NaN
# Albania                            2221.0   1333.0    843.0   1461.0   2361.0
# Algeria                           61892.0  46670.0  49217.0  50963.0  42426.0
# Andorra                               NaN      NaN      NaN      NaN      NaN
# Angola                            12571.0  12186.0   9395.0   6819.0   4965.0
#
#                                      1995     1996     1997     1998     1999
# Country (or dependent territory)
# Afghanistan                           NaN      NaN      NaN      NaN      NaN
# Albania                            2882.0   3200.0   2259.0   2560.0   3209.0
# Algeria                           42066.0  46941.0  48178.0  48188.0  48845.0
# Andorra                               NaN      NaN      NaN      NaN      NaN
# ...

# %%
gdp10 = pd.read_csv("gdp-10s.csv", index_col=0)
gdp10.head()
# Out:
#                                      2000     2001     2002     2003     2004  \
# Country (or dependent territory)
# Afghanistan                           NaN      NaN   4367.0   4553.0   5146.0
# Albania                            3483.0   3928.0   4348.0   5611.0   7185.0
# Algeria                           54749.0  54745.0  56761.0  67864.0  85332.0
# Andorra                            1429.0   1547.0   1758.0   2362.0   2896.0
# Angola                            11166.0  10930.0  15286.0  17813.0  23552.0
#
#                                       2005      2006      2007      2008  \
# Country (or dependent territory)
# Afghanistan                         6167.0    6925.0    8556.0   10297.0
# Albania                             8052.0    8896.0   10677.0   12881.0
# Algeria                           103198.0  117027.0  134977.0  171001.0
# Andorra                             3158.0    3456.0    3952.0    4082.0
# ...

# %%
gdp = pd.concat([gdp00, gdp10], axis=1)
gdp.head()
# Out:
#                                      1990     1991     1992     1993     1994  \
# Country (or dependent territory)
# Afghanistan                           NaN      NaN      NaN      NaN      NaN
# Albania                            2221.0   1333.0    843.0   1461.0   2361.0
# Algeria                           61892.0  46670.0  49217.0  50963.0  42426.0
# Andorra                               NaN      NaN      NaN      NaN      NaN
# Angola                            12571.0  12186.0   9395.0   6819.0   4965.0
#
#                                      1995     1996     1997     1998     1999  \
# Country (or dependent territory)
# Afghanistan                           NaN      NaN      NaN      NaN      NaN
# Albania                            2882.0   3200.0   2259.0   2560.0   3209.0
# Algeria                           42066.0  46941.0  48178.0  48188.0  48845.0
# Andorra                               NaN      NaN      NaN      NaN      NaN
# ...

# %%
gdp.dropna(axis=0, inplace=True)
gdp.head()
# Out:
#                                       1990      1991      1992      1993  \
# Country (or dependent territory)
# Albania                             2221.0    1333.0     843.0    1461.0
# Algeria                            61892.0   46670.0   49217.0   50963.0
# Angola                             12571.0   12186.0    9395.0    6819.0
# Antigua and Barbuda                  459.0     482.0     499.0     535.0
# Argentina                         158024.0  211979.0  255787.0  264429.0
#
#                                       1994      1995      1996      1997  \
# Country (or dependent territory)
# Albania                             2361.0    2882.0    3200.0    2259.0
# Algeria                            42426.0   42066.0   46941.0   48178.0
# Angola                              4965.0    6197.0    7994.0    9388.0
# Antigua and Barbuda                  589.0     577.0     634.0     681.0
# Argentina                         287835.0  288497.0  304282.0  327436.0
#
# ...

# %%
gdp['20y-pct'] = ((gdp['2009'] - gdp['2000']) / gdp['2000']) * 100
gdp.head()
# Out:
#                                       1990      1991      1992      1993  \
# Country (or dependent territory)
# Albania                             2221.0    1333.0     843.0    1461.0
# Algeria                            61892.0   46670.0   49217.0   50963.0
# Angola                             12571.0   12186.0    9395.0    6819.0
# Antigua and Barbuda                  459.0     482.0     499.0     535.0
# Argentina                         158024.0  211979.0  255787.0  264429.0
#
#                                       1994      1995      1996      1997  \
# Country (or dependent territory)
# Albania                             2361.0    2882.0    3200.0    2259.0
# Algeria                            42426.0   42066.0   46941.0   48178.0
# Angola                              4965.0    6197.0    7994.0    9388.0
# Antigua and Barbuda                  589.0     577.0     634.0     681.0
# Argentina                         287835.0  288497.0  304282.0  327436.0
#
# ...

# %%
gdp['10y-pct'] = ((gdp['2005'] - gdp['2000']) / gdp['2000']) * 100
gdp.head()
# Out:
#                                       1990      1991      1992      1993  \
# Country (or dependent territory)
# Albania                             2221.0    1333.0     843.0    1461.0
# Algeria                            61892.0   46670.0   49217.0   50963.0
# Angola                             12571.0   12186.0    9395.0    6819.0
# Antigua and Barbuda                  459.0     482.0     499.0     535.0
# Argentina                         158024.0  211979.0  255787.0  264429.0
#
#                                       1994      1995      1996      1997  \
# Country (or dependent territory)
# Albania                             2361.0    2882.0    3200.0    2259.0
# Algeria                            42426.0   42066.0   46941.0   48178.0
# Angola                              4965.0    6197.0    7994.0    9388.0
# Antigua and Barbuda                  589.0     577.0     634.0     681.0
# Argentina                         287835.0  288497.0  304282.0  327436.0
#
# ...

# %%
gdp.sort_values('20y-pct', ascending=False).head(10)
# Out:
#                                       1990      1991      1992      1993  \
# Country (or dependent territory)
# Equatorial Guinea                    133.0     132.0     160.0     162.0
# Angola                             12571.0   12186.0    9395.0    6819.0
# Chad                                1826.0    1809.0    1886.0    1648.0
# Qatar                               6266.0    5579.0    6384.0    5804.0
# Romania                            38516.0   29070.0   19779.0   26624.0
# Nigeria                            62165.0   60131.0   52275.0   56807.0
# Zambia                              4085.0    3690.0    3614.0    3549.0
# China                             396590.0  413209.0  492148.0  617433.0
# Sudan                               2245.0    2528.0    3100.0    5246.0
# Mongolia                            2678.0    2821.0    1566.0     771.0
#
#                                       1994      1995      1996      1997  \
# Country (or dependent territory)
# ...

# %%
gdp.sort_values('10y-pct', ascending=False).head(10)
# Out:
#                                      1990     1991     1992     1993     1994  \
# Country (or dependent territory)
# Equatorial Guinea                   133.0    132.0    160.0    162.0    120.0
# Chad                               1826.0   1809.0   1886.0   1648.0   1335.0
# Angola                            12571.0  12186.0   9395.0   6819.0   4965.0
# Sudan                              2245.0   2528.0   3100.0   5246.0   5961.0
# Romania                           38516.0  29070.0  19779.0  26624.0  30376.0
# Nigeria                           62165.0  60131.0  52275.0  56807.0  80128.0
# Qatar                              6266.0   5579.0   6384.0   5804.0   5946.0
# Hungary                           34366.0  34754.0  38731.0  40125.0  43167.0
# Zambia                             4085.0   3690.0   3614.0   3549.0   3657.0
# Albania                            2221.0   1333.0    843.0   1461.0   2361.0
#
#                                       1995      1996      1997      1998  \
# ...

# %%
gdp.to_excel('gdp.xlsx')
